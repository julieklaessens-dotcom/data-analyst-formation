# %% [markdown]
# <a href="https://colab.research.google.com/github/julieklaessens-dotcom/data-analyst-formation/blob/main/Notebook_Python_Bases_Week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Semaine 1 — Notebook Python (bases, opérateurs, structures)
#
# *Auteur :* Julie Klaessens
# *Date :* 2025-09-22
# *Objectif :* Découvrir les bases de Python pour l’analyse de données : variables, opérateurs, structures de données, conditions, boucles, et dictionnaires.

# %% [markdown]
# ## 1. Introduction
# Ce notebook compile mes exercices issus de **Dataquest (Part 1 — Cours 1‑2)** et de **séance de coaching avec ChatGPT (Python Basics)**.

# %% [markdown]
# ## 2. Introduction to Python Programming for Data Science

# %% [markdown]
# ###      2.1 Python Programming

# %%
## 2. Programming in Python ##

print(23+7)

## 3. The print() Function ##

print(0+6.99)
print(4.5-3.5)

## 4. Python Syntax ##

print(0.00)
print(2130805)
print(4.5)

## 5. Computer Programs ##

print(1.99+6.99)

## 6. Code Comments ##

# Minecraft: Pocket Edition cost, rating count, and user rating
print(6.99)
print(522012)
print(4.5)

## 7. Arithmetical Operations ##

print(16*10)
print(48/5)
print(5**3)
# Out:
# 30
# 6.99
# 1.0
# 0
# 2130805
# 4.5
# 8.98
# 6.99
# 522012
# 4.5
# 160
# 9.6
# 125

# %% [markdown]
# ### 2.2 Programming Python Variables

# %%
## 1. Saving Values ##

result = 6.99 * 2
print(result)

## 2. Variables ##

minecraft_cost = 6.99
fruit_ninja_cost = 1.99*1
print(minecraft_cost)
print(fruit_ninja_cost + 1.99)
print(fruit_ninja_cost + minecraft_cost)

## 3. Variable Names ##

facebook_rating = 3.5
instagram_rating = 4.5

## 4. Updating Variables ##

rating_count_totals = 698516
# Update rating_count_totals below:
rating_count_totals = rating_count_totals + 522012
print(rating_count_totals)

## 5. Syntax Shortcuts ##

rating_count_totals = 698516
rating_count_totals += 522012
fruit_ninja_totals = 1.99
fruit_ninja_totals *= 4
print(rating_count_totals)
print(fruit_ninja_totals)
# Out:
# 13.98
# 6.99
# 3.98
# 8.98
# 1220528
# 1220528
# 7.96

# %% [markdown]
# ### 2.3 Python Data Types: Integers, Floats, Strings

# %%
## 1. Integers and Floats ##

personal_apps = 0
personal_apps += 1.99
gift_apps = 6.99
gift_apps *= 3
print(personal_apps)
print(gift_apps)

## 2. Conversion Between Types ##

personal_apps = 0
personal_apps += 1.99

gift_apps = 6.99
gift_apps *= 3

print(personal_apps)
print(gift_apps)

# Update the values of personal_apps and gift_apps
# Write your code below this line
personal_apps = round(personal_apps)
gift_apps = int(gift_apps)
print(personal_apps)
print(gift_apps)

## 3. Strings ##

app_name = "Minecraft: Pocket Edition"
average_rating = "4.5"
total_ratings = "522012"
print(app_name)

## 4. Escaping Special Characters ##

slogan = 'Meta\'s AI slogan is "Explore. Create. Do More."'
print(slogan)

## 5. String Concatenation ##

facebook = 'Facebook\'s rating is'
fb_rating_str = '3.5'
fb = facebook +' '+fb_rating_str
print(fb)

## 6. String Conversion ##

facebook = 'Facebook\'s rating is'
fb_rating = 3.5
fb_rating_str = str(fb_rating)
fb = facebook +' '+ fb_rating_str
print(fb)

## 7. Multi-line Strings ##

example = '''Facebook's parent company, Meta, created numerous AI chatbots with 'unique personalities'.
Meta's AI slogan is "Explore. Create. Do More.'''
print(example)
# Out:
# 1.99
# 20.97
# 1.99
# 20.97
# 2
# 20
# Minecraft: Pocket Edition
# Meta's AI slogan is "Explore. Create. Do More."
# Facebook's rating is 3.5
# Facebook's rating is 3.5
# Facebook's parent company, Meta, created numerous AI chatbots with 'unique personalities'.
# Meta's AI slogan is "Explore. Create. Do More.

# %% [markdown]
# ### 2.4 Python Lists

# %%
## 1. Storing Row Elements into Variables ##

track_name_row_2 = 'Instagram'
price_row_2 = 0.0
rating_count_tot_row_2 = 2161558

## 2. Storing Rows as Lists ##

row_2 = ['Instagram', 0.0, 'USD', 2161558, 4.5]
row_3 = ['Clash of Clans', 0.0, 'USD', 2130805, 4.5]

## 3. List Length ##

row_2 = ['Instagram', 0.0, 'USD', 2161558, 4.5]
empty_row = []
row_2_length = len(row_2)
empty_row_length = len(empty_row)

## 4. List Indexing ##

row_1 = ['Facebook', 0.0, 'USD', 2974676, 3.5]
row_2 = ['Instagram', 0.0, 'USD', 2161558, 4.5]
row_3 = ['Clash of Clans', 0.0, 'USD', 2130805, 4.5]
track_name_index = 0
user_rating_index = 4

## 5. Retrieving Values from Lists ##

row_1 = ['Facebook', 0.0, 'USD', 2974676, 3.5]
row_2 = ['Instagram', 0.0, 'USD', 2161558, 4.5]
row_3 = ['Clash of Clans', 0.0, 'USD', 2130805, 4.5]
ratings_1 = row_1[3]
ratings_2 = row_2[3]
ratings_3 = row_3[3]
total = ratings_1 + ratings_2 + ratings_3
average = total / 3

## 6. Negative Indexing ##

row_1 = ['Facebook', 0.0, 'USD', 2974676, 3.5]
row_2 = ['Instagram', 0.0, 'USD', 2161558, 4.5]
row_3 = ['Clash of Clans', 0.0, 'USD', 2130805, 4.5]
rating_1 = row_1[-1]
rating_2 = row_2[-1]
rating_3 = row_3[-1]
total_rating = rating_1 + rating_2 + rating_3
average_rating = total_rating / 3

## 7. Retrieving Multiple List Elements ##

row_1 = ['Facebook', 0.0, 'USD', 2974676, 3.5]
row_2 = ['Instagram', 0.0, 'USD', 2161558, 4.5]
row_3 = ['Clash of Clans', 0.0, 'USD', 2130805, 4.5]
row_4 = ['Fruit Ninja Classic', 1.99, 'USD', 698516, 4.5]
row_5 = ['Minecraft: Pocket Edition', 6.99, 'USD', 522012, 4.5]
fb_rating_data = [row_1[0], row_1[3], row_1[-1]]
insta_rating_data = [row_2[0], row_2[3], row_2[-1]]
minecraft_rating_data = [row_5[0], row_5[3], row_5[-1]]
total_rating = fb_rating_data[2] + insta_rating_data[2] + minecraft_rating_data[2]
average_rating = total_rating / 3

## 8. List Slicing ##

row_1 = ['Facebook', 0.0, 'USD', 2974676, 3.5]
row_2 = ['Instagram', 0.0, 'USD', 2161558, 4.5]
row_3 = ['Clash of Clans', 0.0, 'USD', 2130805, 4.5]
row_4 = ['Fruit Ninja Classic', 1.99, 'USD', 698516, 4.5]
row_5 = ['Minecraft: Pocket Edition', 6.99, 'USD', 522012, 4.5]
last_3_fb = row_1[-3:]
minecraft_3_4 = row_5[2:4]
print(last_3_fb)
print(minecraft_3_4)

## 9. List of Lists ##

row_1 = ['Facebook', 0.0, 'USD', 2974676, 3.5]
row_2 = ['Instagram', 0.0, 'USD', 2161558, 4.5]
row_3 = ['Clash of Clans', 0.0, 'USD', 2130805, 4.5]
row_4 = ['Fruit Ninja Classic', 1.99, 'USD', 698516, 4.5]
row_5 = ['Minecraft: Pocket Edition', 6.99, 'USD', 522012, 4.5]
games_apps = [row_3, row_4, row_5]

## 10. Retrieving from List of Lists ##

row_1 = ['Facebook', 0.0, 'USD', 2974676, 3.5]
row_2 = ['Instagram', 0.0, 'USD', 2161558, 4.5]
row_3 = ['Clash of Clans', 0.0, 'USD', 2130805, 4.5]
row_4 = ['Fruit Ninja Classic', 1.99, 'USD', 698516, 4.5]
row_5 = ['Minecraft: Pocket Edition', 6.99, 'USD', 522012, 4.5]
app_data_set = [row_1, row_2, row_3, row_4, row_5]
avg_rating = (app_data_set[0][-1] + app_data_set[1][-1] + app_data_set[2][-1] + app_data_set[3][-1] + app_data_set[-1][-1]) / 5
# Out:
# ['USD', 2974676, 3.5]
# ['USD', 522012]

# %% [markdown]
# ## 3. Basic Operators and Data Structures in Python

# %% [markdown]
# ### 3.1 Python For Loops

# %%
## 2. For Loops ##

app_names = ['Facebook', 'Instagram', 'Clash of Clans', 'Fruit Ninja Classic', 'Minecraft: Pocket Edition']
for element in app_names:
    print(element)

## 3. For Loops Continued ##

row_1 = ['Facebook', 0.0, 'USD', 2974676, 3.5]
row_2 = ['Instagram', 0.0, 'USD', 2161558, 4.5]
row_3 = ['Clash of Clans', 0.0, 'USD', 2130805, 4.5]
row_4 = ['Fruit Ninja Classic', 1.99, 'USD', 698516, 4.5]
row_5 = ['Minecraft: Pocket Edition', 6.99, 'USD', 522012, 4.5]

app_data_set = [row_1, row_2, row_3, row_4, row_5]

for row in app_data_set:
    rating_count = row[3]
    print(rating_count)

## 4. For Loop Structure ##

row_1 = ['Facebook', 0.0, 'USD', 2974676, 3.5]
row_2 = ['Instagram', 0.0, 'USD', 2161558, 4.5]
row_3 = ['Clash of Clans', 0.0, 'USD', 2130805, 4.5]
row_4 = ['Fruit Ninja Classic', 1.99, 'USD', 698516, 4.5]
row_5 = ['Minecraft: Pocket Edition', 6.99, 'USD', 522012, 4.5]

app_data_set = [row_1, row_2, row_3, row_4, row_5]

rating_sum = 0

for row in app_data_set:
    rating_count = row[3]
    rating_sum += rating_count
    print(rating_sum)

## 5. The Average App Rating ##

row_1 = ['Facebook', 0.0, 'USD', 2974676, 3.5]
row_2 = ['Instagram', 0.0, 'USD', 2161558, 4.5]
row_3 = ['Clash of Clans', 0.0, 'USD', 2130805, 4.5]
row_4 = ['Fruit Ninja Classic', 1.99, 'USD', 698516, 4.5]
row_5 = ['Minecraft: Pocket Edition', 6.99, 'USD', 522012, 4.5]

app_data_set = [row_1, row_2, row_3, row_4, row_5]

rating_sum = 0

for row in app_data_set:
    rating = row[-1]
    rating_sum += rating

avg_rating = rating_sum/5

## 6. Opening a File ##

# --- Étape 1 : Monter Google Drive ---
from google.colab import drive
#drive.mount('/content/drive')

# --- Étape 2 : Utiliser le bon chemin vers AppleStore.csv ---
from csv import reader

opened_file = open('/content/drive/MyDrive/Data/AppleStore.csv', encoding='utf-8')
read_file = reader(opened_file)
apps_data = list(read_file)

print(len(apps_data))
print(apps_data[0])
print(apps_data[1])
print(apps_data[2])

## 8. Dealing with Errors ##

# --- Étape 1 : Monter Google Drive ---
from google.colab import drive
#drive.mount('/content/drive')

# --- Étape 2 : Utiliser le bon chemin vers AppleStore.csv ---
from csv import reader

opened_file = open('/content/drive/MyDrive/Data/AppleStore.csv', encoding='utf-8')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)

rating_sum = 0
for row in apps_data[1:]:
    rating = float(row[8])
    rating_sum += rating

avg_rating = rating_sum/len(apps_data[1:])
print(avg_rating)

## 9. Alternative Method to Calculate an Average ##

# --- Étape 1 : Monter Google Drive ---
from google.colab import drive
#drive.mount('/content/drive')

# --- Étape 2 : Utiliser le bon chemin vers AppleStore.csv ---
from csv import reader

opened_file = open('/content/drive/MyDrive/Data/AppleStore.csv', encoding='utf-8')
read_file = reader(opened_file)
apps_data = list(read_file)

rating_sum = []
for row in apps_data[1:]:
    rating = float(row[8])
    rating_sum.append(rating)

avg_rating = sum(rating_sum)/len(apps_data[1:])
print(avg_rating)
# Out:
# Facebook
# Instagram
# Clash of Clans
# Fruit Ninja Classic
# Minecraft: Pocket Edition
# 2974676
# 2161558
# 2130805
# 698516
# 522012
# 2974676
# 5136234
# 7267039
# 7965555
# 8487567
# 7198
# ['', 'id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
# ['1', '281656475', 'PAC-MAN Premium', '100788224', 'USD', '3.99', '21292', '26', '4', '4.5', '6.3.5', '4+', 'Games', '38', '5', '10', '1']
# ['2', '281796108', 'Evernote - stay organized', '158578688', 'USD', '0', '161065', '26', '4', '3.5', '8.2.2', '4+', 'Productivity', '37', '5', '23', '1']
# 3.526955675976101
# 3.526955675976101

# %% [markdown]
# ### 3.2 Python If, Else, Elif Statements

# %%
## 1. Append Recap ##

# --- Étape 1 : Monter Google Drive ---
from google.colab import drive
drive.mount('/content/drive')

# --- Étape 2 : Utiliser le bon chemin vers AppleStore.csv ---
from csv import reader

opened_file = open('/content/drive/MyDrive/Data/AppleStore.csv', encoding='utf-8')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)

apps_names = []
for row in apps_data[1:]:
    name = row[2]
    apps_names.append(name)

print(apps_names[:5])

## 2. If Statements ##

# --- Étape 1 : Monter Google Drive ---
from google.colab import drive
#drive.mount('/content/drive')

# --- Étape 2 : Utiliser le bon chemin vers AppleStore.csv ---
from csv import reader

opened_file = open('/content/drive/MyDrive/Data/AppleStore.csv', encoding='utf-8')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)

free_apps_ratings = []
for row in apps_data[1:]:
    rating = float(row[8])
    price = float(row[5])

    if price == 0.0:
            free_apps_ratings.append(rating)

avg_rating_free = sum(free_apps_ratings)/len(free_apps_ratings)
print(avg_rating_free)

## 3. The Average Rating of Non-free Apps

# --- Étape 1 : Monter Google Drive ---
from google.colab import drive
#drive.mount('/content/drive')

# --- Étape 2 : Utiliser le bon chemin vers AppleStore.csv ---
from csv import reader

opened_file = open('/content/drive/MyDrive/Data/AppleStore.csv', encoding='utf-8')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)

free_apps_ratings = []
for row in apps_data[1:]:
    rating = float(row[8])
    price = float(row[5])
    if price == 0.0:
        free_apps_ratings.append(rating)

avg_rating_free = sum(free_apps_ratings) / len(free_apps_ratings)
print(avg_rating_free)

non_free_apps_ratings = []
for row in apps_data[1:]:
    rating = float(row[8])
    price = float(row[5])
    if price != 0.0:
        non_free_apps_ratings.append(rating)

avg_rating_non_free = sum(non_free_apps_ratings) / len(non_free_apps_ratings)
print(avg_rating_non_free)

if avg_rating_free >= avg_rating_non_free:
    print("Free apps are better than non-free apps")

## 4. The Average Rating of Non Gaming Apps ##

# --- Étape 1 : Monter Google Drive ---
from google.colab import drive
#drive.mount('/content/drive')

# --- Étape 2 : Utiliser le bon chemin vers AppleStore.csv ---
from csv import reader

opened_file = open('/content/drive/MyDrive/Data/AppleStore.csv', encoding='utf-8')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)

non_games_ratings = []
for row in apps_data[1:]:
    rating = float(row[8])
    genre = row[12]

    if genre != 'Games':
        non_games_ratings.append(rating)

avg_rating_non_games = sum(non_games_ratings)/len(non_games_ratings)
print(avg_rating_non_games)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['PAC-MAN Premium', 'Evernote - stay organized', 'WeatherBug - Local Weather, Radar, Maps, Alerts', 'eBay: Best App to Buy, Sell, Save! Online Shopping', 'Bible']
# 3.3767258382642997
# 3.3767258382642997
# 3.720948742438714
# 3.343928035982009

# %% [markdown]
# ### 3.3 Python If, Else, Elif Statements: Multiple Conditions

# %%
## 1. Multiple Conditions ##

# --- Étape 1 : Monter Google Drive ---
from google.colab import drive
#drive.mount('/content/drive')

# --- Étape 2 : Utiliser le bon chemin vers AppleStore.csv ---
from csv import reader

opened_file = open('/content/drive/MyDrive/Data/AppleStore.csv', encoding='utf-8')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)

free_games_ratings = []
for row in apps_data[1:]:
    rating = float(row[8])
    price = float(row[5])
    genre = row[12]

    if price == 0 and genre == 'Games':
        free_games_ratings.append(rating)

avg_rating_free_games = sum(free_games_ratings)/len(free_games_ratings)
print(avg_rating_free_games)

## 2. The or Operator ##

# --- Étape 1 : Monter Google Drive ---
from google.colab import drive
#drive.mount('/content/drive')

# --- Étape 2 : Utiliser le bon chemin vers AppleStore.csv ---
from csv import reader

opened_file = open('/content/drive/MyDrive/Data/AppleStore.csv', encoding='utf-8')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)

games_social_ratings = []
for row in apps_data[1:]:
    rating = float(row[8])
    genre = row[12]

    if genre == 'Social Networking' or genre == 'Games':
        games_social_ratings.append(rating)

avg_games_social = sum(games_social_ratings)/len(games_social_ratings)
print(avg_games_social)

## 3. Combining Logical Operators ##

# --- Étape 1 : Monter Google Drive ---
from google.colab import drive
#drive.mount('/content/drive')

# --- Étape 2 : Utiliser le bon chemin vers AppleStore.csv ---
from csv import reader

opened_file = open('/content/drive/MyDrive/Data/AppleStore.csv', encoding='utf-8')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)

free_games_social_ratings = []
for row in apps_data[1:]:
    rating = float(row[8])
    genre = row[12]
    price = float(row[5])

    if (genre == 'Social Networking' or genre == 'Games') and price == 0:
        free_games_social_ratings.append(rating)

avg_free = sum(free_games_social_ratings) / len(free_games_social_ratings)
print(avg_free)

# Not-free apps (average)
non_free_games_social_rating = []
for row in apps_data[1:]:
    rating = float(row[8])
    genre = row[12]
    price = float(row[5])

    if (genre == 'Social Networking' or genre == 'Games') and price !=0:
        non_free_games_social_rating.append(rating)

avg_not_free = sum(non_free_games_social_rating)/len(non_free_games_social_rating)
print(avg_not_free)

## 4. Comparison Operator Applications ##

# --- Étape 1 : Monter Google Drive ---
from google.colab import drive
#drive.mount('/content/drive')

# --- Étape 2 : Utiliser le bon chemin vers AppleStore.csv ---
from csv import reader

opened_file = open('/content/drive/MyDrive/Data/AppleStore.csv', encoding='utf-8')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)

apps_price_greater_9 = []
for row in apps_data[1:]:
    rating = float(row[8])
    price = float(row[5])

    if price > 9:
        apps_price_greater_9.append(rating)

avg_rating = sum(apps_price_greater_9)/len(apps_price_greater_9)
print(avg_rating)

n_apps_more_9 = len(apps_price_greater_9)
print(n_apps_more_9)

n_apps_less_9 = len(apps_data[1:])-len(apps_price_greater_9)
print(n_apps_less_9)

## 5. The else Clause ##

# --- Étape 1 : Monter Google Drive ---
from google.colab import drive
#drive.mount('/content/drive')

# --- Étape 2 : Utiliser le bon chemin vers AppleStore.csv ---
from csv import reader

opened_file = open('/content/drive/MyDrive/Data/AppleStore.csv', encoding='utf-8')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)

for app in apps_data[1:]:
    price = float(app[5])

    if price == 0:
        app.append('free')
    else:
        app.append('not free')

apps_data[0].append('free_or_not')
print(apps_data[:6])

## 6. The elif Clause ##

app_ratings = [['Facebook', 3.5], ['Notion', 4.0], ['Astropad Standard', 4.5], ['NAVIGON Europe', 3.5]]

for app in app_ratings:
    rating = app[1]

    if rating < 3:
        app.append('below average')
    elif rating >= 3 and rating < 4:
        app.append('roughly average')
    elif rating >= 4:
        app.append('better than average')

print(app_ratings)

## 7. Else vs. elif ##

# --- Étape 1 : Monter Google Drive ---
from google.colab import drive
#drive.mount('/content/drive')

# --- Étape 2 : Utiliser le bon chemin vers AppleStore.csv ---
from csv import reader

opened_file = open('/content/drive/MyDrive/Data/AppleStore.csv', encoding='utf-8')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)

for app in apps_data[1:]:
    price = float(app[5])

    if price == 0:
        app.append('free')
    elif price > 0 and price < 20:
        app.append('affordable')
    elif price >= 20 and price < 50:
        app.append('expensive')
    elif price >= 50:
        app.append('very expensive')

apps_data[0].append('price_label')
print(apps_data[:6])
# Out:
# 3.5285777580859548
# 3.655994043186895
# 3.496875
# 3.8904235727440146
# 3.5280898876404496
# 178
# 7019
# ...

# %% [markdown]
# ### 3.4 Python Dictionaries and Frequency Tables

# %%
## 1. Counting with Dictionaries ##

# test
content_ratings = {'4+': 0, '9+': 0, '12+': 0, '17+': 0}
ratings = ['4+', '4+', '4+', '9+', '9+', '12+', '17+']

for c_rating in ratings:
    if c_rating in content_ratings:
        content_ratings[c_rating] += 1

print(content_ratings)

# sur la liste AppleStore

# --- Étape 1 : Monter Google Drive ---
from google.colab import drive
#drive.mount('/content/drive')

# --- Étape 2 : Utiliser le bon chemin vers AppleStore.csv ---
from csv import reader

opened_file = open('/content/drive/MyDrive/Data/AppleStore.csv', encoding='utf-8')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)

content_ratings = {'4+': 0, '9+': 0, '12+': 0, '17+': 0}

for row in apps_data[1:]:
    c_rating = row[11]
    if c_rating in content_ratings:
        content_ratings[c_rating] += 1

print(content_ratings)

## 2. Finding the Unique Values ##

# --- Étape 1 : Monter Google Drive ---
from google.colab import drive
#drive.mount('/content/drive')

# --- Étape 2 : Utiliser le bon chemin vers AppleStore.csv ---
from csv import reader

opened_file = open('/content/drive/MyDrive/Data/AppleStore.csv', encoding='utf-8')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)

content_ratings = {}

for row in apps_data[1:]:
    c_rating = row[11]
    if c_rating in content_ratings:
        content_ratings[c_rating] += 1
    else:
        content_ratings[c_rating] = 1

print(content_ratings)

## 3. Proportions and Percentages ##

# --- Étape 1 : Monter Google Drive ---
from google.colab import drive
#drive.mount('/content/drive')

# --- Étape 2 : Utiliser le bon chemin vers AppleStore.csv ---
from csv import reader

opened_file = open('/content/drive/MyDrive/Data/AppleStore.csv', encoding='utf-8')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)

genre_counting = {}

for row in apps_data[1:]:
    genre = row[12]
    if genre in genre_counting:
        genre_counting[genre] += 1
    else:
        genre_counting[genre] = 1

print(genre_counting)

## 4. Looping over Dictionaries ##

content_ratings = {'4+': 4433, '12+': 1155, '9+': 987, '17+': 622}
total_number_of_apps = 7197

for rating in content_ratings:
    content_ratings[rating] /= total_number_of_apps
    content_ratings[rating] *= 100

percentage_17_plus = content_ratings['17+']
percentage_15_allowed = content_ratings['4+'] + content_ratings['9+'] + content_ratings['12+']

print(percentage_17_plus)
print(percentage_15_allowed)

## 5. Keeping the Dictionaries Separate ##

content_ratings = {'4+': 4433, '12+': 1155, '9+': 987, '17+': 622}
total_number_of_apps = 7197

c_ratings_proportions = {}
c_ratings_percentages = {}

for key in content_ratings:
    proportion = content_ratings[key] / total_number_of_apps
    c_ratings_proportions[key] = proportion
    c_ratings_percentages[key] = proportion*100

print(c_ratings_proportions)
print(c_ratings_percentages)

## 6. Frequency Tables for Numerical Columns ##

# --- Étape 1 : Monter Google Drive ---
from google.colab import drive
#drive.mount('/content/drive')

# --- Étape 2 : Utiliser le bon chemin vers AppleStore.csv ---
from csv import reader

opened_file = open('/content/drive/MyDrive/Data/AppleStore.csv', encoding='utf-8')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)

data_sizes = []
for row in apps_data[1:]:
    size = float(row[3])
    data_sizes.append(size)

min_size = min(data_sizes)
max_size = max(data_sizes)
print(min_size)
print(max_size)

## 7. Filtering for the Intervals ##

# --- Étape 1 : Monter Google Drive ---
from google.colab import drive
#drive.mount('/content/drive')

# --- Étape 2 : Utiliser le bon chemin vers AppleStore.csv ---
from csv import reader

opened_file = open('/content/drive/MyDrive/Data/AppleStore.csv', encoding='utf-8')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)

rating_count_tot_list = []
for row in apps_data[1:]:
    liste = float(row[6])
    rating_count_tot_list.append(liste)

min_rating_count_tot = min(rating_count_tot_list)
max_rating_count_tot = max(rating_count_tot_list)

print(min_rating_count_tot)
print(max_rating_count_tot)

rating_count_tot_size = {'0 - 500k': 0, '500k - 1000k': 0, '1000k - 1500k': 0, '1500k - 2000k': 0, '2000k - 2500k': 0, '2500k - 3000k': 0}
for row in apps_data[1:]:
    size = float(row[6])

    if size <= 500000:
        rating_count_tot_size['0 - 500k'] += 1
    elif 500000 < size <= 1000000:
        rating_count_tot_size['500k - 1000k'] += 1
    elif 1000000 < size <= 1500000:
        rating_count_tot_size['1000k - 1500k'] += 1
    elif 1500000 < size <= 2000000:
        rating_count_tot_size['1500k - 2000k'] += 1
    elif 2000000 < size <= 2500000:
        rating_count_tot_size['2000k - 2500k'] += 1
    else:
        rating_count_tot_size['2500k - 3000k'] += 1

print(rating_count_tot_size)
# Out:
# {'4+': 3, '9+': 2, '12+': 1, '17+': 1}
# Mounted at /content/drive
# {'4+': 4433, '9+': 987, '12+': 1155, '17+': 622}
# {'4+': 4433, '12+': 1155, '17+': 622, '9+': 987}
# {'Games': 3862, 'Productivity': 178, 'Weather': 72, 'Shopping': 122, 'Reference': 64, 'Finance': 104, 'Music': 138, 'Utilities': 248, 'Travel': 81, 'Social Networking': 167, 'Sports': 114, 'Business': 57, 'Health & Fitness': 180, 'Entertainment': 535, 'Photo & Video': 349, 'Navigation': 46, 'Education': 453, 'Lifestyle': 144, 'Food & Drink': 63, 'News': 75, 'Book': 112, 'Medical': 23, 'Catalogs': 10}
# 8.642489926358204
# 91.35751007364179
# {'4+': 0.6159510907322495, '12+': 0.16048353480616923, '9+': 0.13714047519799916, '17+': 0.08642489926358204}
# {'4+': 61.595109073224954, '12+': 16.04835348061692, '9+': 13.714047519799916, '17+': 8.642489926358204}
# 589824.0
# 4025969664.0
# 0.0
# 2974676.0
# ...

# %% [markdown]
# ## 4. Exercices coaching

# %%
# 1. Fonction split

phrase = "data is life and life is data"
mots = phrase.split()   # coupe la phrase en mots
compte = {}

for mot in mots:
    if mot in compte:
        compte[mot] +=1
    else:
        compte[mot] = 1
print(compte)
print(phrase.split())

#2. Dictionnaire

notes = {"Alice": 15, "Bob": 9, "Claire": 18, "David": 12}

# Initialisation
reussites = 0
somme_notes = 0

# Parcours du dictionnaire
for etudiant, note in notes.items():
    print(f"{etudiant} a eu {note}")

    # TODO: tester si l'étudiant a réussi (note >= 10)
    if note >= 10:
        reussites += 1
    # et incrémenter reussites si c'est le cas
    somme_notes += note
    # TODO: ajouter la note à somme_notes

# TODO: calculer la moyenne (somme_notes / nombre total d'étudiants)
moyenne = somme_notes/len(notes)
print("Nombre de réussites =", reussites)
print("Moyenne =", moyenne)  # à remplacer

#3. Créer une fonction

def moyenne_notes(dictionnaire):
    somme_notes = 0
    for note in dictionnaire.values():
        somme_notes += note
    return somme_notes/len(dictionnaire)

notes = {"Alice": 15, "Bob": 9, "Claire": 18, "David": 12}
print(moyenne_notes(notes))
# Out:
# {'data': 2, 'is': 2, 'life': 2, 'and': 1}
# ['data', 'is', 'life', 'and', 'life', 'is', 'data']
# Alice a eu 15
# Bob a eu 9
# Claire a eu 18
# David a eu 12
# Nombre de réussites = 3
# Moyenne = 13.5
# 13.5
# range(0, 3)

# %% [markdown]
# ## 5. Conclusion
# - Ce que j’ai appris :
#
#   *   display output of a computer program
#   *   perform arithmetical operations
#   *   store values to variables
#   *   udpate the value stored in a variable
#   *   round a number
#   *   types of variables
#   *   create a list of data points
#   *   create a list of lists
#   *   retrieve list elements
#   *   perform list slicing
#   *   repeat a process using a for loop
#   *   append values to a list
#   *   open a dataset file and use it to create a list of lsits
#   *   convert a string to a float
#   *   add all values in a list
#   *   use an if statement and combine multiple conditions
#   *   use the elif and else clauses
#   *   create a dictionnary
#   *   retrieve individual dictionary values
#   *   check if a value exists in a dictionnary as a key
#   *   use the in operator to check for dictionnary membership
#   *   update dictionnary values
#   *   create a frequency table for the unique values in a column of a dataset
#   *   loop over a dictionary
#   *   compute the frequency for defined intervals
#
# - Références : [Dataquest Part 1 (Cours 1‑2)](https://www.dataquest.io/path/data-analyst/), [Exercises (w3schools)](https://www.w3schools.com/python/python_exercises.asp).
